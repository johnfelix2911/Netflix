# %%
import pandas as pd

# %%
main=pd.read_csv(r"C:\Users\johnf\forks\Netflix\Data\netflix_titles.csv\netflix_titles.csv")
side=pd.read_csv(r"C:\Users\johnf\forks\Netflix\Data\netflix_movies_detailed_up_to_2025.csv")

# %%
main.head()
# Out:
#    show_id   type                             title  \
# 0       s1  Movie              Dick Johnson Is Dead
# 6       s7  Movie  My Little Pony: A New Generation
# 7       s8  Movie                           Sankofa
# 9      s10  Movie                      The Starling
# 12     s13  Movie                      Je Suis Karl
#
#                          director  \
# 0                 Kirsten Johnson
# 6   Robert Cullen, José Luis Ucha
# 7                    Haile Gerima
# 9                  Theodore Melfi
# 12            Christian Schwochow
#
#                                                  cast  \
# 0                                                 NaN
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
#                                               country          date_added  \
# ...

# %%
side.head()
# Out:
#    show_id   type                                         title  \
# 0    10192  Movie                           Shrek Forever After
# 1    27205  Movie                                     Inception
# 2    12444  Movie  Harry Potter and the Deathly Hallows: Part 1
# 3    38757  Movie                                       Tangled
# 4    10191  Movie                      How to Train Your Dragon
#
#                       director  \
# 0                Mike Mitchell
# 1            Christopher Nolan
# 2                  David Yates
# 3   Byron Howard, Nathan Greno
# 4  Chris Sanders, Dean DeBlois
#
#                                                 cast  \
# 0  Mike Myers, Eddie Murphy, Cameron Diaz, Antoni...
# 1  Leonardo DiCaprio, Joseph Gordon-Levitt, Ken W...
# 2  Daniel Radcliffe, Emma Watson, Rupert Grint, T...
# 3  Mandy Moore, Zachary Levi, Donna Murphy, Ron P...
# 4  Jay Baruchel, Gerard Butler, Craig Ferguson, A...
#
# ...

# %%
main=main[main['type']=='Movie']

# %%
len(set(main['title'])-set(side['title']))
# Out:
# 4247

# %%
len(set(side['title'])-set(main['title']))
# Out:
# 13601

# %%
main.shape
# Out:
# (6131, 12)

# %%
side.shape
# Out:
# (16000, 18)

# %%
len(set(main['title']).intersection(set(side['title'])))
# Out:
# 1884

# %%
main.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
side.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'genres', 'language',
#        'description', 'popularity', 'vote_count', 'vote_average', 'budget',
#        'revenue'],
#       dtype='object')

# %%
final=pd.read_csv(r"C:\Users\johnf\forks\Netflix\Data\final_cleaned_main.csv")

# %%
final.head()
# Out:
#    show_id     type                 title         director         cast  \
# 0        1    Movie  Dick Johnson Is Dead  Kirsten Johnson      Unknown
# 1        2  TV Show         Blood & Water          Unknown   Ama Qamata
# 2        2  TV Show         Blood & Water          Unknown   Ama Qamata
# 3        2  TV Show         Blood & Water          Unknown   Ama Qamata
# 4        2  TV Show         Blood & Water          Unknown  Khosi Ngema
#
#          country  date_added  release_year rating   duration      listed_in  \
# 0  United States  2021-09-25          2020  PG-13     90 min  Documentaries
# 1   South Africa  2021-09-24          2021  TV-MA  2 Seasons         Dramas
# 2   South Africa  2021-09-24          2021  TV-MA  2 Seasons  International
# 3   South Africa  2021-09-24          2021  TV-MA  2 Seasons       Thriller
# 4   South Africa  2021-09-24          2021  TV-MA  2 Seasons         Dramas
#
#                                          description  count_cast  \
# ...

# %%
s1=set(final['listed_in'])
s2=set(side['genres'])

# %%
s1-s2
# Out:
# {'Anime',
#  'British',
#  'Children & Family',
#  'Classic',
#  'Classic & Cult',
#  'Comedies',
#  'Cult',
#  'Documentaries',
#  'Documentary Series',
#  'Dramas',
#  'Independent',
#  'International',
#  'LGBTQ',
#  'Movies',
#  'Sci-Fi',
#  'Sci-Fi & Fantasy',
#  'Science & Nature',
#  'Sports',
#  'TV',
#  'Teen'}

# %%
s2-s1
# Out:
# {'Animation, Comedy, Horror',
#  'Adventure, Comedy, Drama',
#  'Science Fiction, Adventure, Mystery',
#  'Adventure, Comedy, Fantasy, Family',
#  'Drama, Fantasy, Romance, Music, Comedy',
#  'Horror, Mystery, Thriller',
#  'Comedy, Crime, Romance',
#  'Action, Adventure, War, History, Fantasy',
#  'Animation, Family, Action, Adventure',
#  'Family, TV Movie, Drama, Romance',
#  'Thriller, Action, Horror, Science Fiction, Mystery',
#  'War, History, Thriller, Action, Crime, Drama',
#  'Thriller, Action, Adventure, Science Fiction',
#  'Drama, Music, History',
#  'Documentary, Music',
#  'Horror, Thriller, Science Fiction',
#  'Family, Science Fiction, Comedy',
#  'Action, Mystery, Thriller, Science Fiction',
#  'Adventure, Comedy, Drama, Horror, Thriller',
#  'Animation, Music, Family, Comedy',
#  'Music, Comedy, Crime',
#  'Adventure, Drama, Family',
#  'Action, Drama, Comedy, Mystery',
#  'Mystery, Action, Adventure, Horror',
#  'Mystery, Fantasy, Comedy, Adventure',
# ...

# %%
final['duration'].unique
# Out:
# <bound method Series.unique of 0            90 min
# 1         2 Seasons
# 2         2 Seasons
# 3         2 Seasons
# 4         2 Seasons
#             ...
# 197773      111 min
# 197774      111 min
# 197775      111 min
# 197776      111 min
# 197777      111 min
# Name: duration, Length: 197778, dtype: object>
